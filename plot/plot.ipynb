# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
expert_rate = np.loadtxt('expert.csv',delimiter=',')
bc_rate = np.loadtxt('bc.csv',delimiter=',')
dqn_rate = np.loadtxt('dqn.csv',delimiter=',')
ppo_rate = np.loadtxt('ppo.csv',delimiter=',')
bc_success_rate = np.loadtxt('bc_success.csv',delimiter=',')
dqn_success_rate = np.loadtxt('dqn_success.csv',delimiter=',')
ppo_success_rate = np.loadtxt('ppo_success.csv',delimiter=',')
old_success_rate = np.loadtxt('old_success.csv',delimiter=',')

# bc_success_rate = np.sum(bc_rate,axis=1)/np.sum(expert_rate,axis=1)
# bc_success_rate = np.max(bc_rate,axis=1)
# dqn_success_rate = np.sum(dqn_rate,axis=1)/np.sum(expert_rate,axis=1)
# dqn_success_rate = np.max(dqn_rate,axis=1)
# ppo_success_rate = np.sum(ppo_rate,axis=1)/np.sum(expert_rate,axis=1)


episode = np.arange(len(bc_rate))

# %%
# 绘制原始数据曲线和平均曲线
plt.plot(bc_success_rate, label='Our Code',color='red',linewidth=2)
plt.plot(old_success_rate, label='Shit_Mountain Code',color='black',linewidth=1)
plt.plot(dqn_success_rate, label='DQN',color='blue',linewidth=0.5,alpha=0.3)
plt.plot(ppo_success_rate, label='PPO',color='green',linewidth=0.5,alpha=0.3)
plt.legend()
plt.xlabel("Episode")
plt.ylabel("Success Ratio")
plt.title("Test Results")
# Out:
# Text(0.5, 1.0, 'Test Results')
